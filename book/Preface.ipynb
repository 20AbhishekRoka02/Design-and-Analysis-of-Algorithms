# %% [markdown]
# # Preface

# %% [markdown]
# This book is written for readers who want to understand algorithms
# as systems of thought rather than as memorized procedures.
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed non
# risus. Suspendisse lectus tortor, dignissim sit amet, adipiscing nec,
# ultricies sed, dolor.
#
# This work emphasizes clarity, mathematical rigor, and practical
# execution. Algorithms are treated not as abstract ideas but as
# mechanisms that operate under constraints of time, space, and
# computation.

# %% [markdown]
# The reader is assumed to have curiosity, patience, and a willingness
# to reason. No prior expertise is required beyond basic programming
# literacy.
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec
# odio. Praesent libero. Sed cursus ante dapibus diam.

# %% [markdown]
# Before diving into theory, let us verify that our computational
# environment is functional by executing a simple C++ program.

# %%
# %%bash
# cat << 'EOF' > hello.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     cout << "Hello from C++ via Binder!" << endl;
#     return 0;
# }
# EOF

# %%
# !g++ hello.cpp -o hello
# Out:
# 'g++' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !./hello
# Out:
# '.' is not recognized as an internal or external command,
# operable program or batch file.
